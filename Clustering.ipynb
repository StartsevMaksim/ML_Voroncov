# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import train_test_split
from Clustering import UGaussianMixture

# %%
data = pd.read_csv('DATA/iris.csv')

# %%
X = data.drop('species', axis=1)
y = data['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
model = GaussianMixture(n_components=2)
model.fit(X_train)
y_p = model.predict_proba(X_test)

# %%
sns.scatterplot(X_train, x='sepal_length', y='petal_length', hue=y_predict)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
x = UGaussianMixture(n_components=2)
x.fit(X_train)
y_predict = x.predict(X)

# %%
sns.scatterplot(X, x='sepal_length', y='petal_length', hue=y_predict)
plt.scatter([m[0] for m in x.means_], [m[2] for m in x.means_], c=['Red'], s=200)

# %%
for cov_matrix in x.cov_matrices_:
    a, b = cov_matrix[0][0], cov_matrix[0][2]
    print(a,b)
# Out:
# 0.14745910438693627 0.021525600461256365
# 0.452546006574594 0.47083419722243536
